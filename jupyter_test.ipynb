# %%
import pandas as pd
from pandas.plotting import scatter_matrix
# %matplotlib inline
import matplotlib.pyplot as plt

ML_PATH="/Users/Rabbitybunny/Documents/ML"
DATA_PATH="data"
DATA=ML_PATH+"/"+DATA_PATH+"/"+"breast-cancer-wisconsin.data";
#id, clump_thickness, unif_cell_size, unif_cell_shape, marg_adhesion, single_epith_cell_size
#bare_nuclei, bland_chrom, norm_nucleoli, mitoses, class

print("##################################################");
print("Reading: " + DATA);
df = pd.read_csv(DATA);
print("##################################################\n");

#df.head()   

#df.info()

#df.describe()

#df.hist(bins=50, figsize=(20, 20));
#plt.show()
 
#df.plot(kind="scatter", x="marg_adhesion", y="bland_chrom", alpha=0.1)

attributeSet = ["clump_thickness", "unif_cell_size", "unif_cell_shape", "marg_adhesion", "single_epith_cell_size", 
                "bare_nuclei", "bland_chrom", "norm_nucleoli", "mitoses", "class"]
scatter_matrix(df[attributeSet], figsize=(30, 30), alpha=0.2)
# Out:
# ##################################################
# Reading: /Users/Rabbitybunny/Documents/ML/data/breast-cancer-wisconsin.data
# ##################################################
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1083c67b8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109c6e0f0>]], dtype=object)
